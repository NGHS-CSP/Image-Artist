# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np  
from PIL import Image
import random

def altering_image_choice(original_image, color1, color2, color3): 
    # Pick from the colors White, Black, Green, Red and Blue
    
    directory = os.getcwd()
    editfile = os.path.join(directory, original_image)
    # Build an absolute filename from directory + filename
    #filename = os.path.join(directory, 'xwoman.jpg')
    # Read the image data into an array
    img = plt.imread(editfile)


    if color1 == 'red':
        b = [255,0,0]
    elif color2 == 'red':
        c = [255,0,0]
    elif color3 == 'red':
        e = [255,0,0]
        
    if color1 == 'blue': 
        b = [0,0,255]
    elif color2 == 'blue':
        c = [0,0,255]
    elif color3 == 'blue':
        e = [0,0,255]
                
    if color1== 'green':
        b = [0,255,0]
    elif color2  == 'green':
        c = [0,255,0]
    elif color3 == 'green':
        e = [0,255,0]
        
    if color1== 'black':
        b = [0,0,0]
    elif color2  == 'black':
        c = [0,0,0]
    elif color3 == 'black':
        e = [0,0,0]
        
    if color1== 'white':
        b = [255,255,255]
    elif color2  == 'white':
        c = [255,255,255]
    elif color3 == 'white':
        e = [255,255,255]
        
    if color1== 'cyan':
        b = [0,255,255]
    elif color2  == 'cyan':
        c = [0,255,255]
    elif color3 == 'cyan':
        e = [0,255,255]
        
    if color1== 'yellow':
        b = [255,255,0]
    elif color2  == 'yellow':
        c = [255,255,0]
    elif color3 == 'yellow':
        e = [255,255,0]
        
    if color1== 'magenta':
        b = [255,0,255]
    elif color2  == 'magenta':
        c = [255,0,255]
    elif color3 == 'magenta':
        e = [255,0,255]
        
    if color1== 'grey' or color1 == 'gray':
        b = [105,105,105]
    elif color2  == 'gray' or color2 == 'grey':
        c = [105,105,105]
    elif color3 == 'grey' or color3 == 'gray':
        e = [105,105,105]
        
        
    if color1== 'brown':
        b = [139,69,19]
    elif color2  == 'brown':
        c = [139,69,19]
    elif color3 == 'brown':
        e = [139,69,19]
        
    if color1== 'orange':
        b = [255,165,0]
    elif color2  == 'orange':
        c = [255,165,0]
    elif color3 == 'orange':
        e = [255,165,0]
        
    if color1== 'pink':
        b = [255,20,147]
    elif color2  == 'pink':
        c = [255,20,147]
    elif color3 == 'pink':
        e = [255,20,147]
        
    if color1== 'purple':
        b = [160,32,240]
    elif color2  == 'purple':
        c = [160,32,240]
    elif color3 == 'purple':
        e = [160,32,240]
        
    if color1== 'forest green':
        b = [34,139,34]
    elif color2  == 'forest green':
        c = [34,139,34]
    elif color3 == 'forest green':
        e = [34,139,34]
        
    if color1== 'navy':
        b = [0,0,128]
    elif color2  == 'navy':
        c = [0,0,128]
    elif color3 == 'navy':
        e = [0,0,128]
        
    if color1== 'sky blue':
        b = [0,191,255]
    elif color2  == 'sky blue':
        c = [0,191,255]
    elif color3 == 'sky blue':
        e = [0,191,255]
        
    if color1== 'aquamarine':
        b = [127,255,212]
    elif color2  == 'aquamarine':
        c = [127,255,212]
    elif color3 == 'aquamarine':
        e = [127,255,212]
        
    if color1== 'turquoise':
        b = [0,206,209]
    elif color2  == 'turquoise':
        c = [0,206,209]
    elif color3 == 'turquoise':
        e = [0,206,209]
        
    height = len(img)
    width = len(img[0])
    for s in range(height):
        for d in range(width):
            a = img[s][d][0] + img[s][d][1] + img[s][d][2]
            if a >= 127:
                img[s][d] = b
            elif a <= 50:
                img[s][d] = c
            else:
                img[s][d] = e   
    
    fig, ax = plt.subplots(1, 1)
    # Show the image data in a subplot
    ax.imshow(img, interpolation='none')

# %%
altering_image_choice('daisies.JPG','black','white','red')
# Out:
# /Users/David/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:150: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import os.path
import numpy as np  
from PIL import Image
import random
import cv2
 
# Camera 0 is the integrated web cam on my netbook
camera_port = 0
 
#Number of frames to throw away while the camera adjusts to light levels
ramp_frames = 30
 
# Now we can initialize the camera capture object with the cv2.VideoCapture class.
# All it needs is the index to a camera port.
camera = cv2.VideoCapture(camera_port)
 
# Captures a single image from the camera and returns it in PIL format
def get_image():
 # read is the easiest way to get a full image out of a VideoCapture object.
 retval, im = camera.read()
 return im
 
# Ramp the camera - these frames will be discarded and are only used to allow v4l2
# to adjust light levels, if necessary
for i in xrange(ramp_frames):
 temp = get_image()
print("Taking image...")
# Take the actual image we want to keep
camera_capture = get_image()
file = "\Users\matthew.zierl\Desktop\dumb.jpg"
# A nice feature of the imwrite method is that it will automatically choose the
# correct format based on the file extension you provide. Convenient!
cv2.imwrite(file, camera_capture)
 
# You'll want to release the camera, otherwise you won't be able to create a new
# capture object until your script exits
del(camera)


def altering_image_choice(original_image, color1, color2, color3): 
    # Pick from the colors White, Black, Green, Red and Blue
    #directory = os.path.dirname(os.path.abspath(__file__)) 
    # Build an absolute filename from directory + filename
    #filename = os.path.join(directory, 'xwoman.jpg')
    directory = os.getcwd()
    pic = original_image
    filename = os.path.join(directory, pic)
    # Read the image data into an array
    img = plt.imread(filename)


    if color1 == 'red':
        b = [255,0,0]
    elif color2 == 'red':
        c = [255,0,0]
    elif color3 == 'red':
        e = [255,0,0]
        
    if color1 == 'blue': 
        b = [0,0,255]
    elif color2 == 'blue':
        c = [0,0,255]
    elif color3 == 'blue':
        e = [0,0,255]
                
    if color1== 'green':
        b = [0,255,0]
    elif color2  == 'green':
        c = [0,255,0]
    elif color3 == 'green':
        e = [0,255,0]
        
    if color1== 'black':
        b = [0,0,0]
    elif color2  == 'black':
        c = [0,0,0]
    elif color3 == 'black':
        e = [0,0,0]
        
    if color1== 'white':
        b = [255,255,255]
    elif color2  == 'white':
        c = [255,255,255]
    elif color3 == 'white':
        e = [255,255,255]
        
    if color1== 'cyan':
        b = [0,255,255]
    elif color2  == 'cyan':
        c = [0,255,255]
    elif color3 == 'cyan':
        e = [0,255,255]
        
    if color1== 'yellow':
        b = [255,255,0]
    elif color2  == 'yellow':
        c = [255,255,0]
    elif color3 == 'yellow':
        e = [255,255,0]
        
    if color1== 'magenta':
        b = [255,0,255]
    elif color2  == 'magenta':
        c = [255,0,255]
    elif color3 == 'magenta':
        e = [255,0,255]
        
    if color1== 'grey' or color1=='gray':
        b = [105,105,105]
    elif color2  == 'gray' or color2=='grey':
        c = [105,105,105]
    elif color3 == 'grey' or color3=='gray':
        e = [105,105,105]
        
    if color1== 'brown':
        b = [139,69,19]
    elif color2  == 'brown':
        c = [139,69,19]
    elif color3 == 'brown':
        e = [139,69,19]
        
    if color1== 'orange':
        b = [255,165,0]
    elif color2  == 'orange':
        c = [255,165,0]
    elif color3 == 'orange':
        e = [255,165,0]
        
    if color1== 'pink':
        b = [255,20,147]
    elif color2  == 'pink':
        c = [255,20,147]
    elif color3 == 'pink':
        e = [255,20,147]
        
    if color1== 'purple':
        b = [160,32,240]
    elif color2  == 'purple':
        c = [160,32,240]
    elif color3 == 'purple':
        e = [160,32,240]
        
    if color1== 'forest green':
        b = [34,139,34]
    elif color2  == 'forest green':
        c = [34,139,34]
    elif color3 == 'forest green':
        e = [34,139,34]
        
    if color1== 'navy':
        b = [0,0,128]
    elif color2  == 'navy':
        c = [0,0,128]
    elif color3 == 'navy':
        e = [0,0,128]
        
    if color1== 'sky blue':
        b = [0,191,255]
    elif color2  == 'sky blue':
        c = [0,191,255]
    elif color3 == 'sky blue':
        e = [0,191,255]
        
    if color1== 'aquamarine':
        b = [127,255,212]
    elif color2  == 'aquamarine':
        c = [127,255,212]
    elif color3 == 'aquamarine':
        e = [127,255,212]
        
    if color1== 'turquoise':
        b = [0,206,209]
    elif color2  == 'turquoise':
        c = [0,206,209]
    elif color3 == 'turquoise':
        e = [0,206,209]
        
    height = len(img)
    width = len(img[0])
    for s in range(height):
        for d in range(width):
                a = img[s][d][0] + img[s][d][1] + img[s][d][2]
                if a >= 127:
                    img[s][d] = b
                elif a < 127 and a >= 50:
                    img[s][d] = c
                elif a < 50:
                    img[s][d] = e   
             
    fig, ax = plt.subplots(1, 1)
    # Show the image data in a subplot
    ax.imshow(img, interpolation='none')
    # Show the figure on the screen



    
altering_image_choice(file,'blue','grey','green')
# Out:
# Taking image...
# /Users/David/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/ipykernel/__main__.py:184: RuntimeWarning: overflow encountered in ubyte_scalars
